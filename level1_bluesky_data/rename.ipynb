# %%
import pandas as pd
import glob

# %%
#get all the files in the directory
files = glob.glob("*.csv")

for file in files:
    #read the file
    df = pd.read_csv(file)
    #get the name of the file
    name = file.split(".")[0]
    name = name.replace('_15minute_average', '')
    df.to_csv(name + ".csv")
